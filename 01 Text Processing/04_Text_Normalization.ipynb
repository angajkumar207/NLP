# %%
import string

# %%
### Special Character
import string
text = "Hello !! world? ,, #angaj @python code: "

translator = str.maketrans('', '', string.punctuation)
cleaned_text = text.translate(translator)
print(cleaned_text)
# Out:
# Hello  world  angaj python code

# %%
## Removing whiteSpace
text = "    Angaj.   Kumar."
cleaned_text = " ".join(text.split())
print(cleaned_text)
print("Lenth of text: ", len(text))
print("Length of Cleaned text: ", len(cleaned_text))
# Out:
# Angaj. Kumar.
# Lenth of text:  19
# Length of Cleaned text:  13

# %%
# !pip install contractions
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import contractions

text = "don't, shalln't, wouldn't,  shouldn't"
expanded_text = contractions.fix(text)
print(expanded_text)
# Out:
# do not, shall not, would not,  should not

# %%
## handling numbers
import re

text = "i have 3 banana and 4 apple"
cleaned_text = re.sub(r'\d+', ' ',  text)
print(cleaned_text)
# Out:
# i have   banana and   apple

# %%
num_to_digit = {
    "3": "Three",
    "4": "Four"
}

# %%
cleaned_text = ""

for char in text:
    if char.isdigit():
        cleaned_text += num_to_digit[char]
    else:
        cleaned_text += char

print(cleaned_text)
# Out:
# i have Three banana and Four apple

# %%
### handling Email URL and Hashtags

text = "Vist https://angaj.com"
processed_text = re.sub(r"http\S+|www\S|https\S+", "URL", text)
print(processed_text)
# Out:
# Vist URL

# %%
# !pip install pyspellchecker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.2 MB 5.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.2 MB 6.2 MB/s eta 0:00:01
#    ------------- -------------------------- 2.4/7.2 MB 4.2 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.2 MB 5.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.2 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.2/7.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 4.8 MB/s eta 0:00:00
# ...

# %%
### Words Spelling check

from spellchecker import SpellChecker

text = "i havde a cars"
spell = SpellChecker()
words = text.split()

corrected_text = " ".join([spell.correction(word) for word in words])
print(corrected_text)
# Out:
# i have a cars
